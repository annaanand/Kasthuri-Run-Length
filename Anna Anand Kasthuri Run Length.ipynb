# %%
import numpy as np
import matplotlib.pyplot as plt
import skimage.exposure as ex

# %%
from intern.remote.boss import BossRemote

# %%
remote = BossRemote({
    "protocol":"https",
    "host":"api.bossdb.io",
    "token": "public"
})

'''config = {"protocol": "https",
    "host": "api.bossdb.io",
    "token": "c751bcbe3e2afa26e7334f61a8a1dcce7245fe50"}
'''
remote = BossRemote(config)

# %%
kasthuri_channel = remote.get_channel("neuron", "Kasthuri", "ac4")
kasthuri = remote.get_cutout(kasthuri_channel, 0, [0,1024], [0,1024], [0,100])

for slice in range(len(kasthuri)):
    plt.imshow(kasthuri[slice])

# %%
kasthuri[neuron[1]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-d0a6a8e39fe1> in <module>
# ----> 1 kasthuri[neuron[1]]
#
# NameError: name 'neuron' is not defined
